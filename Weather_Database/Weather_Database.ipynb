# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Creating URL for Weather Map API Call.
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | rincon
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | laramie
# Processing Record 9 of Set 1 | los llanos de aridane
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | chicama
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | odweyne
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | talawdi
# City not found. Skipping...
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | kimbe
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | coquimbo
# Processing Record 25 of Set 1 | kibala
# Processing Record 26 of Set 1 | magistralnyy
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | maniwaki
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | santa vitoria do palmar
# Processing Record 32 of Set 1 | alofi
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | belokurikha
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | sao filipe
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | petrovsk-zabaykalskiy
# Processing Record 40 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | la asuncion
# Processing Record 44 of Set 1 | buckeye
# Processing Record 45 of Set 1 | itoman
# Processing Record 46 of Set 1 | kruisfontein
# Processing Record 47 of Set 1 | pombas
# Processing Record 48 of Set 1 | iringa
# Processing Record 49 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | lerik
# Processing Record 3 of Set 2 | araouane
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | shimoda
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | bandarbeyla
# Processing Record 8 of Set 2 | denpasar
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | raga
# Processing Record 14 of Set 2 | sinnamary
# Processing Record 15 of Set 2 | namatanai
# Processing Record 16 of Set 2 | mankachar
# Processing Record 17 of Set 2 | shubarkuduk
# Processing Record 18 of Set 2 | buala
# Processing Record 19 of Set 2 | the pas
# Processing Record 20 of Set 2 | dusetos
# Processing Record 21 of Set 2 | thoen
# Processing Record 22 of Set 2 | bangolo
# Processing Record 23 of Set 2 | nemuro
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | jibuti
# Processing Record 29 of Set 2 | porto-vecchio
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | rapu-rapu
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | alice springs
# Processing Record 34 of Set 2 | soroti
# Processing Record 35 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 2 | ambulu
# Processing Record 37 of Set 2 | hudson bay
# Processing Record 38 of Set 2 | waingapu
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | ardahan
# Processing Record 41 of Set 2 | tabas
# Processing Record 42 of Set 2 | inhambane
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | anadyr
# Processing Record 47 of Set 2 | watsa
# Processing Record 48 of Set 2 | stonewall
# Processing Record 49 of Set 2 | acapulco
# Processing Record 50 of Set 2 | praia
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | copiapo
# Processing Record 3 of Set 3 | xichang
# Processing Record 4 of Set 3 | lompoc
# Processing Record 5 of Set 3 | ngunguru
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | kamina
# Processing Record 8 of Set 3 | guarapari
# Processing Record 9 of Set 3 | mitsamiouli
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | fairbanks
# Processing Record 12 of Set 3 | hambantota
# Processing Record 13 of Set 3 | shouguang
# Processing Record 14 of Set 3 | tuatapere
# Processing Record 15 of Set 3 | quelimane
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | saint anthony
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | mangrol
# Processing Record 21 of Set 3 | sao joao da barra
# Processing Record 22 of Set 3 | kavieng
# Processing Record 23 of Set 3 | marzuq
# Processing Record 24 of Set 3 | vestmannaeyjar
# Processing Record 25 of Set 3 | itainopolis
# Processing Record 26 of Set 3 | port-gentil
# Processing Record 27 of Set 3 | mareeba
# Processing Record 28 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 3 | sistranda
# Processing Record 30 of Set 3 | puerto montt
# Processing Record 31 of Set 3 | antofagasta
# Processing Record 32 of Set 3 | kandrian
# Processing Record 33 of Set 3 | anupgarh
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | ringwood
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | gazli
# Processing Record 40 of Set 3 | srednekolymsk
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | puerto narino
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | dikson
# Processing Record 45 of Set 3 | hit
# Processing Record 46 of Set 3 | wanlaweyn
# Processing Record 47 of Set 3 | muros
# Processing Record 48 of Set 3 | narsaq
# Processing Record 49 of Set 3 | bosaso
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | maniitsoq
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | jalu
# Processing Record 8 of Set 4 | linguere
# Processing Record 9 of Set 4 | pilar
# Processing Record 10 of Set 4 | ingham
# Processing Record 11 of Set 4 | kapaa
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | ilheus
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | puquio
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | mudgee
# Processing Record 21 of Set 4 | lorvao
# Processing Record 22 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | vila velha
# Processing Record 24 of Set 4 | port elizabeth
# Processing Record 25 of Set 4 | daru
# Processing Record 26 of Set 4 | coahuayana
# Processing Record 27 of Set 4 | ostersund
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | leh
# Processing Record 30 of Set 4 | sarangani
# Processing Record 31 of Set 4 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | hithadhoo
# Processing Record 34 of Set 4 | mersin
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | arroyo
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | poum
# Processing Record 39 of Set 4 | tucuman
# Processing Record 40 of Set 4 | ennis
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | richards bay
# Processing Record 43 of Set 4 | balkanabat
# Processing Record 44 of Set 4 | saint-pierre
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | camopi
# Processing Record 48 of Set 4 | balikpapan
# Processing Record 49 of Set 4 | rockland
# Processing Record 50 of Set 4 | davila
# Processing Record 1 of Set 5 | mardin
# Processing Record 2 of Set 5 | devils lake
# Processing Record 3 of Set 5 | tekeli
# Processing Record 4 of Set 5 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 5 of Set 5 | grand gaube
# Processing Record 6 of Set 5 | vilhena
# Processing Record 7 of Set 5 | jaunpur
# Processing Record 8 of Set 5 | gizo
# Processing Record 9 of Set 5 | bilma
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | bronnoysund
# Processing Record 13 of Set 5 | touros
# Processing Record 14 of Set 5 | comodoro rivadavia
# Processing Record 15 of Set 5 | georgetown
# Processing Record 16 of Set 5 | kokemaki
# Processing Record 17 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 5 | lubawa
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | xinmin
# Processing Record 21 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | hamada
# Processing Record 24 of Set 5 | brattleboro
# Processing Record 25 of Set 5 | puerto madryn
# Processing Record 26 of Set 5 | mpanda
# Processing Record 27 of Set 5 | salta
# Processing Record 28 of Set 5 | haines junction
# Processing Record 29 of Set 5 | rawson
# Processing Record 30 of Set 5 | taoudenni
# Processing Record 31 of Set 5 | atascadero
# Processing Record 32 of Set 5 | betsiamites
# Processing Record 33 of Set 5 | lebu
# Processing Record 34 of Set 5 | maceio
# Processing Record 35 of Set 5 | placerville
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | gela
# Processing Record 38 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 39 of Set 5 | juba
# Processing Record 40 of Set 5 | urdoma
# Processing Record 41 of Set 5 | tombouctou
# Processing Record 42 of Set 5 | asau
# Processing Record 43 of Set 5 | seoul
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | severo-yeniseyskiy
# Processing Record 46 of Set 5 | gornopravdinsk
# Processing Record 47 of Set 5 | benguela
# Processing Record 48 of Set 5 | bahia de caraquez
# Processing Record 49 of Set 5 | westport
# Processing Record 50 of Set 5 | ofunato
# Processing Record 1 of Set 6 | ferzikovo
# Processing Record 2 of Set 6 | cidreira
# Processing Record 3 of Set 6 | goma
# Processing Record 4 of Set 6 | erenhot
# Processing Record 5 of Set 6 | duiwelskloof
# Processing Record 6 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 6 | kaeo
# Processing Record 8 of Set 6 | kamenka
# Processing Record 9 of Set 6 | saqqez
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | preobrazheniye
# Processing Record 13 of Set 6 | kurilsk
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | vanimo
# Processing Record 16 of Set 6 | ola
# Processing Record 17 of Set 6 | pirovskoye
# Processing Record 18 of Set 6 | dzerzhinskoye
# Processing Record 19 of Set 6 | tengzhou
# Processing Record 20 of Set 6 | prado
# Processing Record 21 of Set 6 | trairi
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | buritizeiro
# Processing Record 24 of Set 6 | cozumel
# Processing Record 25 of Set 6 | hermosillo
# Processing Record 26 of Set 6 | hwange
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | cabra
# Processing Record 29 of Set 6 | mbandaka
# Processing Record 30 of Set 6 | longyearbyen
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | mezen
# Processing Record 35 of Set 6 | ishim
# Processing Record 36 of Set 6 | saskylakh
# Processing Record 37 of Set 6 | islamkot
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | mulchen
# Processing Record 40 of Set 6 | bilibino
# Processing Record 41 of Set 6 | teshie
# Processing Record 42 of Set 6 | svobodnyy
# Processing Record 43 of Set 6 | husavik
# Processing Record 44 of Set 6 | north platte
# Processing Record 45 of Set 6 | rundu
# Processing Record 46 of Set 6 | terney
# Processing Record 47 of Set 6 | hobyo
# Processing Record 48 of Set 6 | beyneu
# Processing Record 49 of Set 6 | chor
# Processing Record 50 of Set 6 | tabuk
# Processing Record 1 of Set 7 | ponta delgada
# Processing Record 2 of Set 7 | mount pleasant
# Processing Record 3 of Set 7 | itaguai
# Processing Record 4 of Set 7 | tezu
# Processing Record 5 of Set 7 | deputatskiy
# Processing Record 6 of Set 7 | hualmay
# Processing Record 7 of Set 7 | marrakesh
# Processing Record 8 of Set 7 | dhidhdhoo
# Processing Record 9 of Set 7 | henties bay
# Processing Record 10 of Set 7 | broken hill
# Processing Record 11 of Set 7 | catamarca
# Processing Record 12 of Set 7 | lagoa
# Processing Record 13 of Set 7 | beloha
# Processing Record 14 of Set 7 | lodja
# Processing Record 15 of Set 7 | ballesteros
# Processing Record 16 of Set 7 | sawtell
# Processing Record 17 of Set 7 | maarianhamina
# Processing Record 18 of Set 7 | aksu
# Processing Record 19 of Set 7 | port lincoln
# Processing Record 20 of Set 7 | eregli
# Processing Record 21 of Set 7 | yulin
# Processing Record 22 of Set 7 | ottawa
# Processing Record 23 of Set 7 | broome
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | norman wells
# Processing Record 26 of Set 7 | gemena
# Processing Record 27 of Set 7 | danville
# Processing Record 28 of Set 7 | waipawa
# Processing Record 29 of Set 7 | sao gabriel da cachoeira
# Processing Record 30 of Set 7 | yungay
# Processing Record 31 of Set 7 | sovetskiy
# Processing Record 32 of Set 7 | loksa
# Processing Record 33 of Set 7 | lindi
# Processing Record 34 of Set 7 | damghan
# Processing Record 35 of Set 7 | rosarito
# Processing Record 36 of Set 7 | jamsa
# Processing Record 37 of Set 7 | stephenville
# Processing Record 38 of Set 7 | wilmington
# Processing Record 39 of Set 7 | havre-saint-pierre
# Processing Record 40 of Set 7 | moranbah
# Processing Record 41 of Set 7 | burnie
# Processing Record 42 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 43 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 7 | chuy
# Processing Record 45 of Set 7 | arlit
# Processing Record 46 of Set 7 | verkhnevilyuysk
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | saint-philippe
# Processing Record 49 of Set 7 | olafsvik
# Processing Record 50 of Set 7 | patitirion
# Processing Record 1 of Set 8 | saint george
# Processing Record 2 of Set 8 | neiafu
# Processing Record 3 of Set 8 | novikovo
# Processing Record 4 of Set 8 | idlib
# Processing Record 5 of Set 8 | chabahar
# Processing Record 6 of Set 8 | abhar
# Processing Record 7 of Set 8 | pauini
# Processing Record 8 of Set 8 | likhoslavl
# Processing Record 9 of Set 8 | praia da vitoria
# Processing Record 10 of Set 8 | avera
# Processing Record 11 of Set 8 | igarka
# Processing Record 12 of Set 8 | keti bandar
# Processing Record 13 of Set 8 | tuysarkan
# City not found. Skipping...
# Processing Record 14 of Set 8 | beringovskiy
# Processing Record 15 of Set 8 | bereznik
# Processing Record 16 of Set 8 | kristiinankaupunki
# Processing Record 17 of Set 8 | hasaki
# Processing Record 18 of Set 8 | khorixas
# Processing Record 19 of Set 8 | atlantic city
# Processing Record 20 of Set 8 | tual
# Processing Record 21 of Set 8 | kousseri
# Processing Record 22 of Set 8 | poltavka
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 25 of Set 8 | vestmanna
# Processing Record 26 of Set 8 | sol-iletsk
# Processing Record 27 of Set 8 | rancho veloz
# Processing Record 28 of Set 8 | soyaniquilpan
# Processing Record 29 of Set 8 | nizhnyaya tura
# Processing Record 30 of Set 8 | bogale
# Processing Record 31 of Set 8 | nueve de julio
# Processing Record 32 of Set 8 | marawi
# Processing Record 33 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 8 | necochea
# Processing Record 36 of Set 8 | viljoenskroon
# Processing Record 37 of Set 8 | banda aceh
# Processing Record 38 of Set 8 | ucluelet
# Processing Record 39 of Set 8 | krasnoslobodsk
# Processing Record 40 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 8 | babu
# Processing Record 42 of Set 8 | erzin
# Processing Record 43 of Set 8 | iqaluit
# Processing Record 44 of Set 8 | binghamton
# Processing Record 45 of Set 8 | kolokani
# Processing Record 46 of Set 8 | college
# Processing Record 47 of Set 8 | jieshi
# Processing Record 48 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 8 | ryotsu
# Processing Record 50 of Set 8 | kushima
# Processing Record 1 of Set 9 | lahan
# Processing Record 2 of Set 9 | coihaique
# Processing Record 3 of Set 9 | boa vista
# Processing Record 4 of Set 9 | kaiyuan
# Processing Record 5 of Set 9 | lata
# Processing Record 6 of Set 9 | pafos
# Processing Record 7 of Set 9 | bogashevo
# Processing Record 8 of Set 9 | humaita
# Processing Record 9 of Set 9 | xinzhi
# Processing Record 10 of Set 9 | margate
# Processing Record 11 of Set 9 | aklavik
# Processing Record 12 of Set 9 | baishishan
# Processing Record 13 of Set 9 | provideniya
# Processing Record 14 of Set 9 | iquitos
# Processing Record 15 of Set 9 | kidal
# Processing Record 16 of Set 9 | masallatah
# Processing Record 17 of Set 9 | san andres
# Processing Record 18 of Set 9 | padang
# Processing Record 19 of Set 9 | chishtian mandi
# Processing Record 20 of Set 9 | korla
# Processing Record 21 of Set 9 | ayagoz
# Processing Record 22 of Set 9 | sterling
# Processing Record 23 of Set 9 | nurlat
# Processing Record 24 of Set 9 | lingao
# Processing Record 25 of Set 9 | aykhal
# Processing Record 26 of Set 9 | banikoara
# Processing Record 27 of Set 9 | akdepe
# Processing Record 28 of Set 9 | esmeraldas
# Processing Record 29 of Set 9 | yebaishou
# Processing Record 30 of Set 9 | karasjok
# Processing Record 31 of Set 9 | bar harbor
# Processing Record 32 of Set 9 | batemans bay
# Processing Record 33 of Set 9 | riachao das neves
# Processing Record 34 of Set 9 | ampanihy
# Processing Record 35 of Set 9 | half moon bay
# Processing Record 36 of Set 9 | totness
# Processing Record 37 of Set 9 | samaipata
# Processing Record 38 of Set 9 | carballo
# Processing Record 39 of Set 9 | qasigiannguit
# Processing Record 40 of Set 9 | gat
# Processing Record 41 of Set 9 | champerico
# Processing Record 42 of Set 9 | victoria
# Processing Record 43 of Set 9 | jaramana
# City not found. Skipping...
# Processing Record 44 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 9 | sakakah
# Processing Record 46 of Set 9 | luganville
# Processing Record 47 of Set 9 | roald
# Processing Record 48 of Set 9 | saint-joseph
# Processing Record 49 of Set 9 | ondjiva
# Processing Record 50 of Set 9 | shumskiy
# Processing Record 1 of Set 10 | santa maria
# Processing Record 2 of Set 10 | lazaro cardenas
# Processing Record 3 of Set 10 | san quintin
# Processing Record 4 of Set 10 | bealanana
# Processing Record 5 of Set 10 | jiangyan
# Processing Record 6 of Set 10 | gouyave
# Processing Record 7 of Set 10 | puerto colombia
# Processing Record 8 of Set 10 | kondinskoye
# Processing Record 9 of Set 10 | povenets
# Processing Record 10 of Set 10 | kamaishi
# Processing Record 11 of Set 10 | panalingaan
# Processing Record 12 of Set 10 | biak
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | dumas
# Processing Record 15 of Set 10 | gilgit
# Processing Record 16 of Set 10 | huilong
# Processing Record 17 of Set 10 | goure
# Processing Record 18 of Set 10 | nguru
# Processing Record 19 of Set 10 | tiznit
# Processing Record 20 of Set 10 | acarau
# Processing Record 21 of Set 10 | bureya
# Processing Record 22 of Set 10 | zheleznodorozhnyy
# Processing Record 23 of Set 10 | flin flon
# Processing Record 24 of Set 10 | bambous virieux
# Processing Record 25 of Set 10 | sibolga
# Processing Record 26 of Set 10 | dunedin
# Processing Record 27 of Set 10 | sapa
# Processing Record 28 of Set 10 | khonsa
# Processing Record 29 of Set 10 | kangaatsiaq
# Processing Record 30 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 10 | adeje
# Processing Record 32 of Set 10 | bahia honda
# Processing Record 33 of Set 10 | faya
# Processing Record 34 of Set 10 | kaya
# Processing Record 35 of Set 10 | mosquera
# Processing Record 36 of Set 10 | tilichiki
# Processing Record 37 of Set 10 | qaqortoq
# Processing Record 38 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 10 | sanmenxia
# Processing Record 40 of Set 10 | port blair
# Processing Record 41 of Set 10 | port hardy
# Processing Record 42 of Set 10 | dicamay
# Processing Record 43 of Set 10 | paamiut
# Processing Record 44 of Set 10 | alpiarca
# Processing Record 45 of Set 10 | soc trang
# Processing Record 46 of Set 10 | kharp
# Processing Record 47 of Set 10 | varhaug
# Processing Record 48 of Set 10 | vila franca do campo
# Processing Record 49 of Set 10 | laguna
# Processing Record 50 of Set 10 | makungu
# Processing Record 1 of Set 11 | paraiso
# Processing Record 2 of Set 11 | te anau
# Processing Record 3 of Set 11 | dali
# Processing Record 4 of Set 11 | sola
# Processing Record 5 of Set 11 | kuanshan
# City not found. Skipping...
# Processing Record 6 of Set 11 | rio grande
# Processing Record 7 of Set 11 | casalmaggiore
# Processing Record 8 of Set 11 | vao
# Processing Record 9 of Set 11 | caravelas
# Processing Record 10 of Set 11 | wattegama
# Processing Record 11 of Set 11 | timmins
# Processing Record 12 of Set 11 | san matias
# Processing Record 13 of Set 11 | flinders
# Processing Record 14 of Set 11 | mulege
# Processing Record 15 of Set 11 | iquique
# Processing Record 16 of Set 11 | palana
# Processing Record 17 of Set 11 | ahuimanu
# Processing Record 18 of Set 11 | nishihara
# Processing Record 19 of Set 11 | rancho palos verdes
# Processing Record 20 of Set 11 | livramento
# Processing Record 21 of Set 11 | umkomaas
# Processing Record 22 of Set 11 | thinadhoo
# Processing Record 23 of Set 11 | tabou
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | linxia
# Processing Record 26 of Set 11 | goch
# Processing Record 27 of Set 11 | homer
# Processing Record 28 of Set 11 | conceicao da barra
# Processing Record 29 of Set 11 | ulaangom
# Processing Record 30 of Set 11 | portland
# Processing Record 31 of Set 11 | mantua
# Processing Record 32 of Set 11 | frutal
# Processing Record 33 of Set 11 | jumla
# Processing Record 34 of Set 11 | sisimiut
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | key west
# Processing Record 37 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 11 | sal rei
# Processing Record 39 of Set 11 | mayor pablo lagerenza
# Processing Record 40 of Set 11 | moissala
# Processing Record 41 of Set 11 | ambilobe
# Processing Record 42 of Set 11 | mwanza
# Processing Record 43 of Set 11 | leningradskiy
# Processing Record 44 of Set 11 | ankara
# Processing Record 45 of Set 11 | brownfield
# Processing Record 46 of Set 11 | le port
# Processing Record 47 of Set 11 | drayton valley
# Processing Record 48 of Set 11 | serebryansk
# Processing Record 49 of Set 11 | grand forks
# Processing Record 50 of Set 11 | krasnoselkup
# Processing Record 1 of Set 12 | waspan
# Processing Record 2 of Set 12 | binzhou
# Processing Record 3 of Set 12 | oblesevo
# Processing Record 4 of Set 12 | malim
# Processing Record 5 of Set 12 | kupino
# Processing Record 6 of Set 12 | huanren
# Processing Record 7 of Set 12 | hibbing
# Processing Record 8 of Set 12 | shingu
# Processing Record 9 of Set 12 | russell
# Processing Record 10 of Set 12 | mutsu
# Processing Record 11 of Set 12 | mombetsu
# Processing Record 12 of Set 12 | vila
# Processing Record 13 of Set 12 | shasta lake
# Processing Record 14 of Set 12 | hami
# Processing Record 15 of Set 12 | esso
# Processing Record 16 of Set 12 | mancio lima
# Processing Record 17 of Set 12 | bassar
# Processing Record 18 of Set 12 | barcelona
# Processing Record 19 of Set 12 | kalabo
# Processing Record 20 of Set 12 | sao jose da coroa grande
# Processing Record 21 of Set 12 | rio verde de mato grosso
# Processing Record 22 of Set 12 | severomuysk
# Processing Record 23 of Set 12 | maningrida
# Processing Record 24 of Set 12 | camacha
# Processing Record 25 of Set 12 | puerto leguizamo
# Processing Record 26 of Set 12 | balabac
# Processing Record 27 of Set 12 | weiser
# Processing Record 28 of Set 12 | port bannatyne
# Processing Record 29 of Set 12 | zhuhai
# Processing Record 30 of Set 12 | mount gambier
# Processing Record 31 of Set 12 | quatre cocos
# Processing Record 32 of Set 12 | zamhlay
# City not found. Skipping...
# Processing Record 33 of Set 12 | markova
# Processing Record 34 of Set 12 | zhaotong
# Processing Record 35 of Set 12 | belyy yar
# Processing Record 36 of Set 12 | kavaratti
# Processing Record 37 of Set 12 | moron
# Processing Record 38 of Set 12 | ende
# Processing Record 39 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 12 | constantine
# Processing Record 41 of Set 12 | krivosheino
# Processing Record 42 of Set 12 | nehe
# Processing Record 43 of Set 12 | buenos aires
# Processing Record 44 of Set 12 | byron bay
# Processing Record 45 of Set 12 | capao bonito
# Processing Record 46 of Set 12 | tiarei
# Processing Record 47 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 12 | sitka
# Processing Record 49 of Set 12 | obihiro
# Processing Record 50 of Set 12 | murray bridge
# Processing Record 1 of Set 13 | knysna
# Processing Record 2 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 13 | millinocket
# Processing Record 4 of Set 13 | karratha
# Processing Record 5 of Set 13 | arman
# Processing Record 6 of Set 13 | kholtoson
# Processing Record 7 of Set 13 | guider
# Processing Record 8 of Set 13 | katobu
# Processing Record 9 of Set 13 | owando
# Processing Record 10 of Set 13 | manakara
# Processing Record 11 of Set 13 | songea
# Processing Record 12 of Set 13 | wanning
# Processing Record 13 of Set 13 | gazojak
# Processing Record 14 of Set 13 | samarai
# Processing Record 15 of Set 13 | lardos
# Processing Record 16 of Set 13 | burica
# City not found. Skipping...
# Processing Record 17 of Set 13 | macenta
# Processing Record 18 of Set 13 | phalodi
# Processing Record 19 of Set 13 | alcantara
# Processing Record 20 of Set 13 | zhicheng
# Processing Record 21 of Set 13 | guerrero negro
# Processing Record 22 of Set 13 | kathmandu
# Processing Record 23 of Set 13 | uyuni
# Processing Record 24 of Set 13 | manokwari
# Processing Record 25 of Set 13 | baykit
# Processing Record 26 of Set 13 | bonavista
# Processing Record 27 of Set 13 | vallenar
# Processing Record 28 of Set 13 | trelew
# Processing Record 29 of Set 13 | zyryanskoye
# Processing Record 30 of Set 13 | awjilah
# Processing Record 31 of Set 13 | awbari
# Processing Record 32 of Set 13 | piacabucu
# Processing Record 33 of Set 13 | hamilton
# Processing Record 34 of Set 13 | jardim
# Processing Record 35 of Set 13 | zhangjiakou
# Processing Record 36 of Set 13 | kasempa
# Processing Record 37 of Set 13 | redmond
# Processing Record 38 of Set 13 | darhan
# Processing Record 39 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 41 of Set 13 | grande-riviere
# City not found. Skipping...
# Processing Record 42 of Set 13 | ilhabela
# Processing Record 43 of Set 13 | gumdag
# Processing Record 44 of Set 13 | bathsheba
# Processing Record 45 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 13 | itarema
# Processing Record 47 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 48 of Set 13 | jurm
# Processing Record 49 of Set 13 | andenes
# Processing Record 50 of Set 13 | safranbolu
# Processing Record 1 of Set 14 | nanortalik
# Processing Record 2 of Set 14 | talnakh
# Processing Record 3 of Set 14 | honiara
# Processing Record 4 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 14 | yerbogachen
# Processing Record 6 of Set 14 | nakhon phanom
# Processing Record 7 of Set 14 | bera
# Processing Record 8 of Set 14 | brae
# Processing Record 9 of Set 14 | plymouth
# Processing Record 10 of Set 14 | fort nelson
# Processing Record 11 of Set 14 | san rafael
# Processing Record 12 of Set 14 | kungurtug
# Processing Record 13 of Set 14 | sheltozero
# Processing Record 14 of Set 14 | nikki
# Processing Record 15 of Set 14 | san cristobal
# Processing Record 16 of Set 14 | moose factory
# Processing Record 17 of Set 14 | pak phanang
# Processing Record 18 of Set 14 | khurai
# Processing Record 19 of Set 14 | roblin
# Processing Record 20 of Set 14 | zhigansk
# Processing Record 21 of Set 14 | torbay
# Processing Record 22 of Set 14 | moussoro
# Processing Record 23 of Set 14 | akcaabat
# Processing Record 24 of Set 14 | tomatlan
# Processing Record 25 of Set 14 | susanino
# Processing Record 26 of Set 14 | tabanan
# Processing Record 27 of Set 14 | ruteng
# Processing Record 28 of Set 14 | jiuquan
# Processing Record 29 of Set 14 | uyovu
# Processing Record 30 of Set 14 | kindu
# Processing Record 31 of Set 14 | dhankuta
# Processing Record 32 of Set 14 | qafqafa
# Processing Record 33 of Set 14 | amga
# Processing Record 34 of Set 14 | yaan
# Processing Record 35 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 14 | aktash
# Processing Record 37 of Set 14 | gourcy
# Processing Record 38 of Set 14 | chiknayakanhalli
# Processing Record 39 of Set 14 | verkhoyansk
# Processing Record 40 of Set 14 | fort smith
# Processing Record 41 of Set 14 | gold coast
# Processing Record 42 of Set 14 | lavrentiya
# Processing Record 43 of Set 14 | maragheh
# Processing Record 44 of Set 14 | maragogi
# Processing Record 45 of Set 14 | umm lajj
# Processing Record 46 of Set 14 | cholet
# Processing Record 47 of Set 14 | sierra vista
# Processing Record 48 of Set 14 | turukhansk
# Processing Record 49 of Set 14 | plettenberg bay
# Processing Record 50 of Set 14 | magomeni
# Processing Record 1 of Set 15 | kresttsy
# Processing Record 2 of Set 15 | horsham
# Processing Record 3 of Set 15 | guangyuan
# Processing Record 4 of Set 15 | fort dodge
# Processing Record 5 of Set 15 | fukuma
# Processing Record 6 of Set 15 | old saybrook
# Processing Record 7 of Set 15 | schmalkalden
# Processing Record 8 of Set 15 | kutum
# Processing Record 9 of Set 15 | abejorral
# Processing Record 10 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 15 | beasain
# Processing Record 12 of Set 15 | shelburne
# Processing Record 13 of Set 15 | palmer
# Processing Record 14 of Set 15 | magadan
# Processing Record 15 of Set 15 | berbera
# Processing Record 16 of Set 15 | sabang
# Processing Record 17 of Set 15 | mahanoro
# Processing Record 18 of Set 15 | las vegas
# Processing Record 19 of Set 15 | kaili
# Processing Record 20 of Set 15 | pandan
# Processing Record 21 of Set 15 | dinguiraye
# Processing Record 22 of Set 15 | vaitape
# Processing Record 23 of Set 15 | george
# Processing Record 24 of Set 15 | port macquarie
# Processing Record 25 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 15 | gualaquiza
# Processing Record 28 of Set 15 | buraydah
# Processing Record 29 of Set 15 | balykshi
# Processing Record 30 of Set 15 | komsomolskiy
# Processing Record 31 of Set 15 | mehamn
# Processing Record 32 of Set 15 | porto novo
# Processing Record 33 of Set 15 | shache
# Processing Record 34 of Set 15 | esil
# Processing Record 35 of Set 15 | natal
# Processing Record 36 of Set 15 | ishigaki
# Processing Record 37 of Set 15 | ulladulla
# Processing Record 38 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 39 of Set 15 | sidhi
# Processing Record 40 of Set 15 | eyl
# Processing Record 41 of Set 15 | la sarrosa
# Processing Record 42 of Set 15 | callaway
# Processing Record 43 of Set 15 | bintulu
# Processing Record 44 of Set 15 | kalaleh
# Processing Record 45 of Set 15 | sao felix do xingu
# Processing Record 46 of Set 15 | santa rosa
# Processing Record 47 of Set 15 | colares
# Processing Record 48 of Set 15 | fez
# Processing Record 49 of Set 15 | morant bay
# Processing Record 50 of Set 15 | yunyang
# Processing Record 1 of Set 16 | jardim de piranhas
# Processing Record 2 of Set 16 | borovskoy
# Processing Record 3 of Set 16 | guiren
# Processing Record 4 of Set 16 | metro
# Processing Record 5 of Set 16 | rio tinto
# Processing Record 6 of Set 16 | dubai
# Processing Record 7 of Set 16 | barcelos
# Processing Record 8 of Set 16 | binuangan
# Processing Record 9 of Set 16 | katsuura
# Processing Record 10 of Set 16 | rio gallegos
# Processing Record 11 of Set 16 | tottori
# Processing Record 12 of Set 16 | monrovia
# Processing Record 13 of Set 16 | kedrovyy
# Processing Record 14 of Set 16 | sohag
# Processing Record 15 of Set 16 | tarko-sale
# Processing Record 16 of Set 16 | tullahoma
# Processing Record 17 of Set 16 | papendrecht
# Processing Record 18 of Set 16 | eureka
# Processing Record 19 of Set 16 | zambezi
# Processing Record 20 of Set 16 | orumiyeh
# Processing Record 21 of Set 16 | columbus
# Processing Record 22 of Set 16 | hemsedal
# Processing Record 23 of Set 16 | kuusamo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Hilo      US  19.7297 -155.0900     79.61        77
# 1        Arraial Do Cabo      BR -22.9661  -42.0278     75.06        78
# 2              Jamestown      US  42.0970  -79.2353     68.52        57
# 3                 Albany      US  42.6001  -73.9662     67.68        78
# 4                 Rincon      US  32.2960  -81.2354     87.71        55
# 5                  Vaini      TO -21.2000 -175.2000     71.76        94
# 6             Bredasdorp      ZA -34.5322   20.0403     57.27        86
# 7                Laramie      US  41.3114 -105.5911     71.91        26
# 8  Los Llanos De Aridane      ES  28.6585  -17.9182     74.12        87
# 9            East London      ZA -33.0153   27.9116     63.46        74
#
#    Cloudiness  Wind Speed Current Description
# 0          75        0.00          light rain
# 1           0       20.71           clear sky
# 2           1        3.00           clear sky
# 3         100        5.61     overcast clouds
# 4          40        0.00    scattered clouds
# 5          20        5.75          few clouds
# 6          86        4.56     overcast clouds
# 7          83       15.75       broken clouds
# 8          20       17.27        volcanic ash
# 9         100        9.06     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
